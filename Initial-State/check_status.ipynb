# %%
import pandas as pd

df = pd.read_parquet(
    "data/manifest/url_status.parquet"
)

print(df.head())
print(df.info())
# Out:
#                            url_hash  \
# 0  ab7309946ad8e617bfafa0d25652665a
# 1  636536804af248aef5d55316676e4fe5
# 2  fedf077f8a234f3ad8889e6e4c338c24
# 3  190405ed0d34411b5e36f8630240100d
# 4  8d6a11cfb55ae38c544434c2e8b7dcb6
#
#                                                  url  http_status  \
# 0  https://pbs.twimg.com/profile_images/378800000...          404
# 1  https://scontent-ord1-1.cdninstagram.com/t51.2...            0
# 2  https://pbs.twimg.com/profile_images/712357386...          404
# 3  https://scontent-ord1-1.cdninstagram.com/t51.2...            0
# 4  https://pbs.twimg.com/profile_images/283131778...          200
#
#   content_type  is_valid                                      error_message  \
# 0                      0                                           HTTP 404
# 1                      0  HTTPSConnectionPool(host='scontent-ord1-1.cdni...
# 2   image/jpeg         0                                           HTTP 404
# ...

# %%
df[df["http_status"] != "ok"].head(20)
# Out:
#                             url_hash  \
# 0   ab7309946ad8e617bfafa0d25652665a
# 1   636536804af248aef5d55316676e4fe5
# 2   fedf077f8a234f3ad8889e6e4c338c24
# 3   190405ed0d34411b5e36f8630240100d
# 4   8d6a11cfb55ae38c544434c2e8b7dcb6
# 5   0f716b5fd2b4e74a707960f3cce1bd48
# 6   c76e314363d1b9415c97240c04d7047d
# 7   f86d59935c42f12b01650ea5d69b4477
# 8   c35c4a850de4618259aaff15ac577e8f
# 9   1d09f54d108292399efcf51e08b73e99
# 10  7b627177a02b6598ebfcfc26615d5691
# 11  f34203a932a8a9ff7816cf037be5b4c8
# 12  c255c514bb80a0c8a97a4ed06a989d79
# 13  ce37f62b4fdcf3ad222f33aff71060f1
# 14  f185cb7f2ec819abadb700619caf6678
# 15  af24d5c18f1b8259c84437757b02bfad
# 16  71c651c8ad14f97ae707cc72b7530923
# 17  b57d7c7bd23647862740e588928f828d
# 18  7e58d72955281ea3d0cb9c18fec32c78
# 19  b6e0ceaa6dad935c6001447a14cca2b8
#
#                                                   url  http_status  \
# 0   https://pbs.twimg.com/profile_images/378800000...          404
# ...

# %%
df["http_status"].value_counts()
# Out:
# http_status
# 0      7765
# 404    5952
# 200      15
# 403      11
# Name: count, dtype: int64
